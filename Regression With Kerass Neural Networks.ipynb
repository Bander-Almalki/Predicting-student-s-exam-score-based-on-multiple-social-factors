# %% [markdown]
# # Neural Network with keras

# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### Loading data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

data= pd.read_csv("student-mat.csv")
print (data)
# Out:
#     school  sex  age  address  famsize  Pstatus  Medu  Fedu      Mjob  \
# 0       GP    0   15        1        0        1     4     4  services
# 1       GP    0   16        1        0        1     4     3    health
# 2       GP    0   16        0        0        1     4     4   teacher
# 3       GP    1   17        1        0        1     4     4  services
# 4       GP    0   16        1        0        1     2     1     other
# ..     ...  ...  ...      ...      ...      ...   ...   ...       ...
# 390     GP    0   18        1        1        1     1     1     other
# 391     GP    0   18        1        1        1     3     3  services
# 392     GP    0   16        1        1        1     4     3   teacher
# 393     GP    0   17        0        1        1     1     1     other
# 394     GP    0   18        0        1        1     3     3     other
#
#          Fjob  ... famrel  freetime  goout  Dalc  Walc  health  absences  G1  \
# ...

# %%
import pandas as pd
import numpy as np
 
# create dataset
df = pd.DataFrame(data)
df=df.drop(columns=['school'])
 
# display dataset
print(df)
 
# create dummy variables
data2=pd.get_dummies(df)
data2
# Out:
#      sex  age  address  famsize  Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      0   15        1        0        1     4     4  services   teacher
# 1      0   16        1        0        1     4     3    health  services
# 2      0   16        0        0        1     4     4   teacher   teacher
# 3      1   17        1        0        1     4     4  services   teacher
# 4      0   16        1        0        1     2     1     other     other
# ..   ...  ...      ...      ...      ...   ...   ...       ...       ...
# 390    0   18        1        1        1     1     1     other     other
# 391    0   18        1        1        1     3     3  services    health
# 392    0   16        1        1        1     4     3   teacher     other
# 393    0   17        0        1        1     1     1     other  services
# 394    0   18        0        1        1     3     3     other  services
#
#          reason  ...  famrel  freetime  goout  Dalc  Walc  health  absences  \
# ...

# %% [markdown]
# ### setting x and y (input and target)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X=data2.drop(columns=['G1','G2','G3'])
X
# Out:
#      sex  age  address  famsize  Pstatus  Medu  Fedu  guardian  traveltime  \
# 0      0   15        1        0        1     4     4         6           1
# 1      0   16        1        0        1     4     3         5           1
# 2      0   16        0        0        1     4     4         5           1
# 3      1   17        1        0        1     4     4         5           2
# 4      0   16        1        0        1     2     1         5           3
# ..   ...  ...      ...      ...      ...   ...   ...       ...         ...
# 390    0   18        1        1        1     1     1         5           1
# 391    0   18        1        1        1     3     3         6           1
# 392    0   16        1        1        1     4     3         5           1
# 393    0   17        0        1        1     1     1         5           4
# 394    0   18        0        1        1     3     3         5           1
#
# ...

# %%
y=data2[['G1','G2','G3']]
y
# Out:
#      G1  G2  G3
# 0    19  18  18
# 1    19  19  20
# 2    18  18  18
# 3    18  18  18
# 4    18  18  18
# ..   ..  ..  ..
# 390   6   5   0
# 391   6   6   8
# 392   6   0   0
# 393   5   8   7
# 394   3   5   5
#
# [395 rows x 3 columns]

# %% [markdown]
# ### Basic Neural Network with 1 input layer and 1 output layer

# %%
# define base model
def baseline_model():
    # create model
    model = Sequential()
    model.add(Dense(40, input_dim=40, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# evaluate model
estimator = KerasRegressor(build_fn=baseline_model, epochs=11)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, y, cv=kfold)
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Epoch 1/11
# C:\Users\Tornado\AppData\Local\Temp\ipykernel_46524\2639067413.py:2: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   estimator = KerasRegressor(build_fn=baseline_model, epochs=11)
# 12/12 [==============================] - 0s 816us/step - loss: 91.6212
# Epoch 2/11
# 12/12 [==============================] - 0s 725us/step - loss: 72.0678
# Epoch 3/11
# 12/12 [==============================] - 0s 818us/step - loss: 52.0747
# Epoch 4/11
# 12/12 [==============================] - 0s 723us/step - loss: 33.2794
# Epoch 5/11
# 12/12 [==============================] - 0s 818us/step - loss: 19.9603
# Epoch 6/11
# 12/12 [==============================] - 0s 816us/step - loss: 15.3400
# Epoch 7/11
# 12/12 [==============================] - 0s 816us/step - loss: 15.1700
# Epoch 8/11
# ...

# %%
res=-(results.mean())
np.sqrt(res)
# Out:
# 4.353028419995135

# %% [markdown]
# ### Neural Network with input layer, 1 hidden layer, 1 output layer

# %%
# define the model
def larger_model():
    # create model
    model = Sequential()
    model.add(Dense(40, input_dim=40, kernel_initializer='normal', activation='relu'))
    model.add(Dense(30, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# evaluate model
estimator = KerasRegressor(build_fn=larger_model, epochs=11, batch_size=5)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, y, cv=kfold)
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Epoch 1/11
# C:\Users\Tornado\AppData\Local\Temp\ipykernel_46524\592262463.py:2: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   estimator = KerasRegressor(build_fn=larger_model, epochs=11, batch_size=5)
# 71/71 [==============================] - 0s 632us/step - loss: 74.3831
# Epoch 2/11
# 71/71 [==============================] - 0s 653us/step - loss: 14.7772
# Epoch 3/11
# 71/71 [==============================] - 0s 611us/step - loss: 13.5135
# Epoch 4/11
# 71/71 [==============================] - 0s 612us/step - loss: 13.1521
# Epoch 5/11
# 71/71 [==============================] - 0s 651us/step - loss: 12.6404
# Epoch 6/11
# 71/71 [==============================] - 0s 652us/step - loss: 12.3889
# Epoch 7/11
# 71/71 [==============================] - 0s 617us/step - loss: 12.2849
# Epoch 8/11
# ...

# %%
res=-(results.mean())
np.sqrt(res)
# Out:
# 4.190103524324389

# %% [markdown]
# ### Neural Network with input layer, 2 hidden layers, 1 output layer

# %%
# define the model
def Deep_model():
    # create model
    model = Sequential()
    model.add(Dense(40, input_dim=40, kernel_initializer='normal', activation='relu'))
    model.add(Dense(30, kernel_initializer='normal', activation='relu'))
    model.add(Dense(10, kernel_initializer='normal', activation='relu'))

    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# evaluate model
estimator = KerasRegressor(build_fn=Deep_model, epochs=20, batch_size=5)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, y, cv=kfold)
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Epoch 1/20
# C:\Users\Tornado\AppData\Local\Temp\ipykernel_46524\4211054000.py:2: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   estimator = KerasRegressor(build_fn=Deep_model, epochs=20, batch_size=5)
# 71/71 [==============================] - 0s 621us/step - loss: 88.3346
# Epoch 2/20
# 71/71 [==============================] - 0s 650us/step - loss: 15.1171
# Epoch 3/20
# 71/71 [==============================] - 0s 670us/step - loss: 13.9874
# Epoch 4/20
# 71/71 [==============================] - 0s 660us/step - loss: 14.0280
# Epoch 5/20
# 71/71 [==============================] - 0s 671us/step - loss: 13.0837
# Epoch 6/20
# 71/71 [==============================] - 0s 670us/step - loss: 12.8086
# Epoch 7/20
# 71/71 [==============================] - 0s 663us/step - loss: 12.3203
# Epoch 8/20
# ...

# %%
res=-(results.mean())
np.sqrt(res)
# Out:
# 3.997980412618907
